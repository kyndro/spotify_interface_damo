# %%
import spotipy
import urllib.request
import random
import requests
import nltk
import webbrowser
import json
from nltk import pos_tag
import spotipy.util as util
import http.client

# %%
from requests import post

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import json

# %%
# open file with keys and set the path to your credentials JSON file
# r= read 
credentials = "example_spotify.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
api_tokens
# Out:
# {'username': 'zu91nihm12fol1t0p9510hpa0',
#  'client_id': '95b6078c108c4d188b53695335665c54',
#  'client_secret': 'de2471d40dd54c30bff0252024a6df52',
#  'redirect': 'http://google.com/'}

# %%
# read the keys and assign each to a variable
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]

# %%
print(client_id, client_secret)
# Out:
# 95b6078c108c4d188b53695335665c54 de2471d40dd54c30bff0252024a6df52

# %%
#client_credentials_manager= object that hold on client id
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)

# %%
#spotify api have 4 items
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]
redirectURI = api_tokens["redirect"]
username = api_tokens["username"]

# %%
scope = 'user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public'
token = util.prompt_for_user_token(username, scope, client_id=client_id,
                           client_secret=client_secret,
                           redirect_uri=redirectURI)

# %%
#create spotify object
#setting the authorization with the final key, ie the token
sp = spotipy.Spotify(auth=token)

# %%
devices= sp.devices()
print(devices['devices'])
#deviceID=devices['devices'][0]['id']
#this is tie to the spotify account
# Out:
# []

# %%
#moonphase
import requests

def get_moon_phase(year, month, day):
    url = f'https://aa.usno.navy.mil/api/moon/phases/date?date={year:04d}-{month:02d}-{day:02d}'
   # print(url)
    # Make the request
    response = requests.get(url)
    
    # Parse the JSON response
    data = response.json()
    
    # Extract moon phase information from the response
    moon_phase = data['phasedata'][0]['phase']

    return moon_phase

# Example usage
year = 2023
month = 3
day = 1

moon_phase = get_moon_phase(year, month, day)
#if moon_phase=='Last Quarter':
    #energy=0.25
#elif moon_phase=='Full':
    #energy=1
#else:
    #energy=0
#print(f'Moon phase on {year}-{month:02d}-{day:02d}: {moon_phase}')
print(moon_phase)
# Out:
# Full Moon

# %%
moon_phase = get_moon_phase(year, month, day)

if moon_phase == 'Last Quarter':
    genre = ["electropop", "modern rock"]
   
elif moon_phase == 'Full moon':
   genre = ["art pop", "soundtrack"]
    
else:
   genre = ["taiwan indie", "korean indie rock"]
print(genre)
# Out:
# ['taiwan indie', 'korean indie rock']

# %%
#moon_list= sp.search(q=f'genre:{genre}', type = 'track', limit =40)
moon_list=[]
for single_genre in genre:
    moon_list.append( sp.search(q=f'genre:{single_genre}', type = 'track', limit =40))
moon_list
# Out:
# [{'tracks': {'href': 'https://api.spotify.com/v1/search?query=genre%3Ataiwan+indie&type=track&offset=0&limit=40',
#    'items': [{'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0JeQFUYo8H7c5K8VIICIIH'},
#         'href': 'https://api.spotify.com/v1/artists/0JeQFUYo8H7c5K8VIICIIH',
#         'id': '0JeQFUYo8H7c5K8VIICIIH',
#         'name': '緩緩 Huan Huan',
#         'type': 'artist',
#         'uri': 'spotify:artist:0JeQFUYo8H7c5K8VIICIIH'}],
#       'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
# ...

# %%
#使用spotipy 提取藝術家流派和歌曲發行日期

# High Energy -modern rock
high_genre = ["baroque pop", "electropop", "modern rock"]
high_result = sp.search(q=f'genre:{high_genre}', type = 'track', limit =40)

# Medium Energy - Art Pop
medium_genre = ["art pop"]
medium_result = sp.search(q=f'genre:{medium_genre}', type = 'track', limit =40)

# Low Energy -  folk
low_genre =  ["taiwan indie","korean indie rock", "soundtrack"]
low_result = sp.search(q=f'genre:{low_genre}', type = 'track', limit =40)

# %%
# High Energy -modern rock
highgenre_results=[]
for genre in high_genre:
    highgenre_results.append( sp.search(q=f'genre:{genre}', type = 'track', limit =40))
    #print(genre)

# Medium Energy -Art Pop
medium_results=[]
for genre in high_genre:
    medium_results.append( sp.search(q=f'genre:{genre}', type = 'track', limit =40))
    
# Low Energy -  folk
lowgenre_results=[]
for genre in low_genre:
    lowgenre_results.append( sp.search(q=f'genre:{genre}', type = 'track', limit =14))
    #print(genre)

# %%
#print(lowgenre_results[0])

# %%
#print(highgenre_results[0])

# %%
#track is a list
high_tracks = highgenre_results[0]['tracks']['items']
#for loop only work on list=[]
medium_tracks = mediumgenre_results[0]['tracks']['items']
low_tracks = lowgenre_results['tracks']['items']

# %%
lowgenre_results[14]['uri']

# %%
# URI = uniform resource identifier
track_selection_list = []
#track_art = []

for song in high_tracks:
    track_selection_list.append(song['uri'])
    #track_art.append(song['album']['images'][0]['url'])
for song in low_tracks:
    track_selection_list.append(song['uri'])

# %%
len(track_selection_list)
# Out:
# 54

# %%
#MAKE A PLAYLIST!!!!!!!!!!AUHHHHHHH
#Make an empty playist
my_playlist = sp.user_playlist_create(user=username, name="Dance under the moon", public=True,
                                      description="welcome to the dance fever")
print(my_playlist)
# Out:
# {'collaborative': False, 'description': 'welcome to the dance fever', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/1SjAuXxUL78n6vCGzpZEaC'}, 'followers': {'href': None, 'total': 0}, 'href': 'https://api.spotify.com/v1/playlists/1SjAuXxUL78n6vCGzpZEaC', 'id': '1SjAuXxUL78n6vCGzpZEaC', 'images': [], 'name': 'Dance under the moon', 'owner': {'display_name': 'kyndro', 'external_urls': {'spotify': 'https://open.spotify.com/user/zu91nihm12fol1t0p9510hpa0'}, 'href': 'https://api.spotify.com/v1/users/zu91nihm12fol1t0p9510hpa0', 'id': 'zu91nihm12fol1t0p9510hpa0', 'type': 'user', 'uri': 'spotify:user:zu91nihm12fol1t0p9510hpa0'}, 'primary_color': None, 'public': True, 'snapshot_id': 'MSw5YmYxZGIyZTdkNjA4ZWFlZWEwYjM2NzFlYWEyMzJmMWI0MTU2NjJl', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/1SjAuXxUL78n6vCGzpZEaC/tracks', 'items': [], 'limit': 100, 'next': None, 'offset': 0, 'previous': None, 'total': 0}, 'type': 'playlist', 'uri': 'spotify:playlist:1SjAuXxUL78n6vCGzpZ
# ...

# %%
#add songs into the playist
results = sp.user_playlist_add_tracks(username, my_playlist['id'], track_selection_list)
print(results)
# Out:
# {'snapshot_id': 'MyxiMjg0OTBkYjNmOTkzYTI5ZjNhN2RlMDlmZDVlOWVlYzA3YWQ4YmZl'}

# %%
# sp.start_playback(deviceID, None, track_selection_list)
#open playist
webbrowser.open(my_playlist['external_urls']['spotify'])
# Out:
# True

# %%
# Out:
# New Moon
